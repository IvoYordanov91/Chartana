# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('marketingcampaigns.csv', sep=',', on_bad_lines='skip')

# %%
df.head(5)
# Out:
#                                    campaign_name  start_date    end_date  \
# 0            Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1             De-engineered analyzing task-force  2023-02-15  2024-04-22
# 2  Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 3              Distributed real-time methodology  2022-09-26  2023-09-27
# 4            Front-line executive infrastructure  2023-07-07  2024-05-15
#
#      budget   roi          type target_audience    channel  conversion_rate  \
# 0    8082.3  0.35         email             B2B    organic             0.40
# 1  17712.98  0.74         email             B2C  promotion             0.66
# 2   84643.1  0.37       podcast             B2B       paid             0.28
# 3  14589.75  0.47       webinar             B2B    organic             0.19
# 4   39291.9  0.30  social media             B2B  promotion             0.81
#
#      revenue
# 0  709593.48
# 1  516609.10
# 2  458227.42
# 3   89958.73
# 4   47511.35

# %%
df.isnull().sum()
# Out:
# campaign_name      0
# start_date         1
# end_date           2
# budget             3
# roi                4
# type               1
# target_audience    2
# channel            1
# conversion_rate    4
# revenue            3
# dtype: int64

# %%
def count_duplicates(data_frame):
    df_copy = data_frame.copy()
    for col in df_copy.select_dtypes(include='object').columns:
        df_copy[col] = df_copy[col].str.lower()

    duplicate_counts = {}
    for col in df_copy.columns:
        duplicate_counts[col] = df_copy.duplicated(subset=[col]).sum()

    return pd.Series(duplicate_counts, name='Duplicate Count')

duplicates = count_duplicates(df)
print(duplicates)
# Out:
# campaign_name        18
# start_date          684
# end_date            684
# budget               20
# roi                 939
# type               1025
# target_audience    1028
# channel            1027
# conversion_rate     939
# revenue              23
# Name: Duplicate Count, dtype: int64

# %%
duplicates = df[df.duplicated(subset=['campaign_name'], keep=False)]
duplicates
# Out:
#                                       campaign_name  start_date    end_date  \
# 0               Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1                De-engineered analyzing task-force  2023-02-15  2024-04-22
# 2     Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 3                 Distributed real-time methodology  2022-09-26  2023-09-27
# 4               Front-line executive infrastructure  2023-07-07  2024-05-15
# 5            Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 6            Innovative context-sensitive framework  2023-03-01  2024-02-23
# 7          User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 8                     Proactive neutral methodology  2022-09-06  2024-01-11
# 9                      Intuitive responsive support  2022-11-25  2024-04-04
# 10                Multi-lateral dedicated workforce  2023-06-15  2024-06-15
# 11            Cross-platform demand-driven encoding  2023-07-21  2023-11-04
# 203        Reverse-engineered static infrastructure  2023-07-26  2024-05-29
# 985        Reverse-engineered static infrastructure  2023-07-16  2023-08-07
# 1000            Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1001  Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 1002              Distributed real-time methodology  2022-09-26  2023-09-27
# 1003         Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 1004       User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 1009            Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1010             De-engineered analyzing task-force  2023-02-15  2024-04-22
# 1011  Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 1012              Distributed real-time methodology  2022-09-26  2023-09-27
# 1013            Front-line executive infrastructure  2023-07-07  2024-05-15
# 1014         Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 1015         Innovative context-sensitive framework  2023-03-01  2024-02-23
# 1016       User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 1017                  Proactive neutral methodology  2022-09-06  2024-01-11
# 1018                   Intuitive responsive support  2022-11-25  2024-04-04
# 1019              Multi-lateral dedicated workforce  2023-06-15  2024-06-15
# 1020          Cross-platform demand-driven encoding  2023-07-21  2023-11-04
#
#         budget   roi          type target_audience    channel  \
# 0       8082.3  0.35         email             B2B    organic
# 1     17712.98  0.74         email             B2C  promotion
# 2      84643.1  0.37       podcast             B2B       paid
# 3     14589.75  0.47       webinar             B2B    organic
# 4      39291.9  0.30  social media             B2B  promotion
# 5     75569.28  0.59  social media             B2C   referral
# 6     28964.45  0.59         email             B2C   referral
# 7     36800.58  0.40       webinar             B2C  promotion
# 8     40493.88  0.16       webinar             B2C    organic
# 9      1816.22  0.81  social media             B2C   referral
# 10    94084.21  0.58       podcast             B2B   referral
# 11    64041.37  0.16  social media             B2B  promotion
# 203   12246.32  0.48         email             B2B   referral
# 985    7315.35  0.86         email             B2C   referral
# 1000    8082.3  0.35         email             B2B    organic
# 1001   84643.1  0.37       podcast             B2B       paid
# 1002  14589.75  0.47       webinar             B2B    organic
# 1003       NaN  0.59  social media             B2C   referral
# 1004  36800.58  0.40           NaN             B2C  promotion
# 1009    8082.3  0.35         email             B2B    organic
# 1010  17712.98  0.74         email             B2C  promotion
# 1011   84643.1  0.37       podcast             B2B       paid
# 1012  14589.75  0.47       webinar             B2B    organic
# 1013   39291.9  0.30  social media             B2B  promotion
# 1014  75569.28  0.59  social media             B2C   referral
# 1015  28964.45  0.59         email             B2C   referral
# 1016  36800.58  0.40       webinar             B2C  promotion
# 1017  40493.88  0.16       webinar             B2C    organic
# 1018   1816.22  0.81  social media             B2C   referral
# 1019  94084.21  0.58       podcast             B2B   referral
# 1020  64041.37  0.16  social media             B2B  promotion
#
#       conversion_rate    revenue
# 0                0.40  709593.48
# 1                0.66  516609.10
# 2                0.28  458227.42
# 3                0.19   89958.73
# 4                0.81   47511.35
# 5                0.67  558302.11
# 6                0.17  172882.59
# 7                0.52  206241.46
# 8                0.47  734755.76
# 9                0.85  563280.30
# 10               0.23  406522.77
# 11               0.55  174462.47
# 203              0.44  987205.29
# 985              0.70  162798.55
# 1000             0.40  709593.48
# 1001             0.28  458227.42
# 1002             0.19   89958.73
# 1003             0.67  558302.11
# 1004             0.52  206241.46
# 1009             0.40  709593.48
# 1010             0.66  516609.10
# 1011             0.28  458227.42
# 1012             0.19   89958.73
# 1013             0.81   47511.35
# 1014             0.67  558302.11
# 1015             0.17  172882.59
# 1016             0.52  206241.46
# 1017             0.47  734755.76
# 1018             0.85  563280.30
# 1019             0.23  406522.77
# 1020             0.55  174462.47

# %%
# Create a lowercase version of the column to check duplicates case-insensitively
df['campaign_name_lower'] = df['campaign_name'].str.lower().str.strip()

# Get rows with duplicate campaign names (case-insensitive)
duplicates = df[df.duplicated(subset=['campaign_name_lower'], keep=False)]
duplicates
# Out:
#                                       campaign_name  start_date    end_date  \
# 0               Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1                De-engineered analyzing task-force  2023-02-15  2024-04-22
# 2     Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 3                 Distributed real-time methodology  2022-09-26  2023-09-27
# 4               Front-line executive infrastructure  2023-07-07  2024-05-15
# 5            Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 6            Innovative context-sensitive framework  2023-03-01  2024-02-23
# 7          User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 8                     Proactive neutral methodology  2022-09-06  2024-01-11
# 9                      Intuitive responsive support  2022-11-25  2024-04-04
# 10                Multi-lateral dedicated workforce  2023-06-15  2024-06-15
# 11            Cross-platform demand-driven encoding  2023-07-21  2023-11-04
# 203        Reverse-engineered static infrastructure  2023-07-26  2024-05-29
# 985        Reverse-engineered static infrastructure  2023-07-16  2023-08-07
# 1000            Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1001  Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 1002              Distributed real-time methodology  2022-09-26  2023-09-27
# 1003         Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 1004       User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 1009            Public-key multi-tasking throughput  2023-04-01  2024-02-23
# 1010             De-engineered analyzing task-force  2023-02-15  2024-04-22
# 1011  Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11
# 1012              Distributed real-time methodology  2022-09-26  2023-09-27
# 1013            Front-line executive infrastructure  2023-07-07  2024-05-15
# 1014         Upgradable transitional data-warehouse  2023-06-29  2023-12-13
# 1015         Innovative context-sensitive framework  2023-03-01  2024-02-23
# 1016       User-friendly client-driven service-desk  2023-01-06  2023-12-11
# 1017                  Proactive neutral methodology  2022-09-06  2024-01-11
# 1018                   Intuitive responsive support  2022-11-25  2024-04-04
# 1019              Multi-lateral dedicated workforce  2023-06-15  2024-06-15
# 1020          Cross-platform demand-driven encoding  2023-07-21  2023-11-04
#
#         budget   roi          type target_audience    channel  \
# 0       8082.3  0.35         email             B2B    organic
# 1     17712.98  0.74         email             B2C  promotion
# 2      84643.1  0.37       podcast             B2B       paid
# 3     14589.75  0.47       webinar             B2B    organic
# 4      39291.9  0.30  social media             B2B  promotion
# 5     75569.28  0.59  social media             B2C   referral
# 6     28964.45  0.59         email             B2C   referral
# 7     36800.58  0.40       webinar             B2C  promotion
# 8     40493.88  0.16       webinar             B2C    organic
# 9      1816.22  0.81  social media             B2C   referral
# 10    94084.21  0.58       podcast             B2B   referral
# 11    64041.37  0.16  social media             B2B  promotion
# 203   12246.32  0.48         email             B2B   referral
# 985    7315.35  0.86         email             B2C   referral
# 1000    8082.3  0.35         email             B2B    organic
# 1001   84643.1  0.37       podcast             B2B       paid
# 1002  14589.75  0.47       webinar             B2B    organic
# 1003       NaN  0.59  social media             B2C   referral
# 1004  36800.58  0.40           NaN             B2C  promotion
# 1009    8082.3  0.35         email             B2B    organic
# 1010  17712.98  0.74         email             B2C  promotion
# 1011   84643.1  0.37       podcast             B2B       paid
# 1012  14589.75  0.47       webinar             B2B    organic
# 1013   39291.9  0.30  social media             B2B  promotion
# 1014  75569.28  0.59  social media             B2C   referral
# 1015  28964.45  0.59         email             B2C   referral
# 1016  36800.58  0.40       webinar             B2C  promotion
# 1017  40493.88  0.16       webinar             B2C    organic
# 1018   1816.22  0.81  social media             B2C   referral
# 1019  94084.21  0.58       podcast             B2B   referral
# 1020  64041.37  0.16  social media             B2B  promotion
#
#       conversion_rate    revenue  \
# 0                0.40  709593.48
# 1                0.66  516609.10
# 2                0.28  458227.42
# 3                0.19   89958.73
# 4                0.81   47511.35
# 5                0.67  558302.11
# 6                0.17  172882.59
# 7                0.52  206241.46
# 8                0.47  734755.76
# 9                0.85  563280.30
# 10               0.23  406522.77
# 11               0.55  174462.47
# 203              0.44  987205.29
# 985              0.70  162798.55
# 1000             0.40  709593.48
# 1001             0.28  458227.42
# 1002             0.19   89958.73
# 1003             0.67  558302.11
# 1004             0.52  206241.46
# 1009             0.40  709593.48
# 1010             0.66  516609.10
# 1011             0.28  458227.42
# 1012             0.19   89958.73
# 1013             0.81   47511.35
# 1014             0.67  558302.11
# 1015             0.17  172882.59
# 1016             0.52  206241.46
# 1017             0.47  734755.76
# 1018             0.85  563280.30
# 1019             0.23  406522.77
# 1020             0.55  174462.47
#
#                                 campaign_name_lower
# 0               public-key multi-tasking throughput
# 1                de-engineered analyzing task-force
# 2     balanced solution-oriented local area network
# 3                 distributed real-time methodology
# 4               front-line executive infrastructure
# 5            upgradable transitional data-warehouse
# 6            innovative context-sensitive framework
# 7          user-friendly client-driven service-desk
# 8                     proactive neutral methodology
# 9                      intuitive responsive support
# 10                multi-lateral dedicated workforce
# 11            cross-platform demand-driven encoding
# 203        reverse-engineered static infrastructure
# 985        reverse-engineered static infrastructure
# 1000            public-key multi-tasking throughput
# 1001  balanced solution-oriented local area network
# 1002              distributed real-time methodology
# 1003         upgradable transitional data-warehouse
# 1004       user-friendly client-driven service-desk
# 1009            public-key multi-tasking throughput
# 1010             de-engineered analyzing task-force
# 1011  balanced solution-oriented local area network
# 1012              distributed real-time methodology
# 1013            front-line executive infrastructure
# 1014         upgradable transitional data-warehouse
# 1015         innovative context-sensitive framework
# 1016       user-friendly client-driven service-desk
# 1017                  proactive neutral methodology
# 1018                   intuitive responsive support
# 1019              multi-lateral dedicated workforce
# 1020          cross-platform demand-driven encoding

# %%
df.columns
# Out:
# Index(['campaign_name', 'start_date', 'end_date', 'budget', 'roi', 'type',
#        'target_audience', 'channel', 'conversion_rate', 'revenue',
#        'campaign_name_lower'],
#       dtype='object')

# %%
# Strip all column names
df.columns = df.columns.str.strip()

# Handle date columns with format inference
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], errors='coerce')

# Function to convert comma to dot and then to float
def to_float(val):
    if isinstance(val, str):
        val = val.replace(',', '.').replace('%', '').strip()
    try:
        return float(val)
    except:
        return None

# Apply to relevant numeric columns
for col in ['budget', 'roi', 'conversion_rate', 'revenue']:
    df[col] = df[col].apply(to_float)

# Confirm types visually (optional)
print(df.dtypes)
# Out:
# campaign_name                  object
# start_date             datetime64[ns]
# end_date               datetime64[ns]
# budget                        float64
# roi                           float64
# type                           object
# target_audience                object
# channel                        object
# conversion_rate               float64
# revenue                       float64
# campaign_name_lower            object
# dtype: object

# %%
# Find rows with duplicate campaign names AND same start & end dates
duplicates_same_dates = df[df.duplicated(subset=['campaign_name_lower', 'start_date', 'end_date', 'budget', 'roi', 'type','target_audience', 'channel', 'conversion_rate', 'revenue' ], keep=False)]

# Display them
duplicates_same_dates
# Out:
#                                       campaign_name start_date   end_date  \
# 0               Public-key multi-tasking throughput 2023-04-01 2024-02-23
# 1                De-engineered analyzing task-force 2023-02-15 2024-04-22
# 2     Balanced solution-oriented Local Area Network 2022-12-20 2023-10-11
# 3                 Distributed real-time methodology 2022-09-26 2023-09-27
# 4               Front-line executive infrastructure 2023-07-07 2024-05-15
# 5            Upgradable transitional data-warehouse 2023-06-29 2023-12-13
# 6            Innovative context-sensitive framework 2023-03-01 2024-02-23
# 7          User-friendly client-driven service-desk 2023-01-06 2023-12-11
# 8                     Proactive neutral methodology 2022-09-06 2024-01-11
# 9                      Intuitive responsive support 2022-11-25 2024-04-04
# 10                Multi-lateral dedicated workforce 2023-06-15 2024-06-15
# 11            Cross-platform demand-driven encoding 2023-07-21 2023-11-04
# 1000            Public-key multi-tasking throughput 2023-04-01 2024-02-23
# 1001  Balanced solution-oriented Local Area Network 2022-12-20 2023-10-11
# 1002              Distributed real-time methodology 2022-09-26 2023-09-27
# 1009            Public-key multi-tasking throughput 2023-04-01 2024-02-23
# 1010             De-engineered analyzing task-force 2023-02-15 2024-04-22
# 1011  Balanced solution-oriented Local Area Network 2022-12-20 2023-10-11
# 1012              Distributed real-time methodology 2022-09-26 2023-09-27
# 1013            Front-line executive infrastructure 2023-07-07 2024-05-15
# 1014         Upgradable transitional data-warehouse 2023-06-29 2023-12-13
# 1015         Innovative context-sensitive framework 2023-03-01 2024-02-23
# 1016       User-friendly client-driven service-desk 2023-01-06 2023-12-11
# 1017                  Proactive neutral methodology 2022-09-06 2024-01-11
# 1018                   Intuitive responsive support 2022-11-25 2024-04-04
# 1019              Multi-lateral dedicated workforce 2023-06-15 2024-06-15
# 1020          Cross-platform demand-driven encoding 2023-07-21 2023-11-04
#
#         budget   roi          type target_audience    channel  \
# 0      8082.30  0.35         email             B2B    organic
# 1     17712.98  0.74         email             B2C  promotion
# 2     84643.10  0.37       podcast             B2B       paid
# 3     14589.75  0.47       webinar             B2B    organic
# 4     39291.90  0.30  social media             B2B  promotion
# 5     75569.28  0.59  social media             B2C   referral
# 6     28964.45  0.59         email             B2C   referral
# 7     36800.58  0.40       webinar             B2C  promotion
# 8     40493.88  0.16       webinar             B2C    organic
# 9      1816.22  0.81  social media             B2C   referral
# 10    94084.21  0.58       podcast             B2B   referral
# 11    64041.37  0.16  social media             B2B  promotion
# 1000   8082.30  0.35         email             B2B    organic
# 1001  84643.10  0.37       podcast             B2B       paid
# 1002  14589.75  0.47       webinar             B2B    organic
# 1009   8082.30  0.35         email             B2B    organic
# 1010  17712.98  0.74         email             B2C  promotion
# 1011  84643.10  0.37       podcast             B2B       paid
# 1012  14589.75  0.47       webinar             B2B    organic
# 1013  39291.90  0.30  social media             B2B  promotion
# 1014  75569.28  0.59  social media             B2C   referral
# 1015  28964.45  0.59         email             B2C   referral
# 1016  36800.58  0.40       webinar             B2C  promotion
# 1017  40493.88  0.16       webinar             B2C    organic
# 1018   1816.22  0.81  social media             B2C   referral
# 1019  94084.21  0.58       podcast             B2B   referral
# 1020  64041.37  0.16  social media             B2B  promotion
#
#       conversion_rate    revenue  \
# 0                0.40  709593.48
# 1                0.66  516609.10
# 2                0.28  458227.42
# 3                0.19   89958.73
# 4                0.81   47511.35
# 5                0.67  558302.11
# 6                0.17  172882.59
# 7                0.52  206241.46
# 8                0.47  734755.76
# 9                0.85  563280.30
# 10               0.23  406522.77
# 11               0.55  174462.47
# 1000             0.40  709593.48
# 1001             0.28  458227.42
# 1002             0.19   89958.73
# 1009             0.40  709593.48
# 1010             0.66  516609.10
# 1011             0.28  458227.42
# 1012             0.19   89958.73
# 1013             0.81   47511.35
# 1014             0.67  558302.11
# 1015             0.17  172882.59
# 1016             0.52  206241.46
# 1017             0.47  734755.76
# 1018             0.85  563280.30
# 1019             0.23  406522.77
# 1020             0.55  174462.47
#
#                                 campaign_name_lower
# 0               public-key multi-tasking throughput
# 1                de-engineered analyzing task-force
# 2     balanced solution-oriented local area network
# 3                 distributed real-time methodology
# 4               front-line executive infrastructure
# 5            upgradable transitional data-warehouse
# 6            innovative context-sensitive framework
# 7          user-friendly client-driven service-desk
# 8                     proactive neutral methodology
# 9                      intuitive responsive support
# 10                multi-lateral dedicated workforce
# 11            cross-platform demand-driven encoding
# 1000            public-key multi-tasking throughput
# 1001  balanced solution-oriented local area network
# 1002              distributed real-time methodology
# 1009            public-key multi-tasking throughput
# 1010             de-engineered analyzing task-force
# 1011  balanced solution-oriented local area network
# 1012              distributed real-time methodology
# 1013            front-line executive infrastructure
# 1014         upgradable transitional data-warehouse
# 1015         innovative context-sensitive framework
# 1016       user-friendly client-driven service-desk
# 1017                  proactive neutral methodology
# 1018                   intuitive responsive support
# 1019              multi-lateral dedicated workforce
# 1020          cross-platform demand-driven encoding

# %%
duplicates_same_dates.value_counts()
# Out:
# campaign_name                                  start_date  end_date    budget    roi   type          target_audience  channel    conversion_rate  revenue    campaign_name_lower
# Balanced solution-oriented Local Area Network  2022-12-20  2023-10-11  84643.10  0.37  podcast       B2B              paid       0.28             458227.42  balanced solution-oriented local area network    3
# Distributed real-time methodology              2022-09-26  2023-09-27  14589.75  0.47  webinar       B2B              organic    0.19             89958.73   distributed real-time methodology                3
# Public-key multi-tasking throughput            2023-04-01  2024-02-23  8082.30   0.35  email         B2B              organic    0.40             709593.48  public-key multi-tasking throughput              3
# Cross-platform demand-driven encoding          2023-07-21  2023-11-04  64041.37  0.16  social media  B2B              promotion  0.55             174462.47  cross-platform demand-driven encoding            2
# De-engineered analyzing task-force             2023-02-15  2024-04-22  17712.98  0.74  email         B2C              promotion  0.66             516609.10  de-engineered analyzing task-force               2
# Front-line executive infrastructure            2023-07-07  2024-05-15  39291.90  0.30  social media  B2B              promotion  0.81             47511.35   front-line executive infrastructure              2
# Innovative context-sensitive framework         2023-03-01  2024-02-23  28964.45  0.59  email         B2C              referral   0.17             172882.59  innovative context-sensitive framework           2
# Intuitive responsive support                   2022-11-25  2024-04-04  1816.22   0.81  social media  B2C              referral   0.85             563280.30  intuitive responsive support                     2
# Multi-lateral dedicated workforce              2023-06-15  2024-06-15  94084.21  0.58  podcast       B2B              referral   0.23             406522.77  multi-lateral dedicated workforce                2
# Proactive neutral methodology                  2022-09-06  2024-01-11  40493.88  0.16  webinar       B2C              organic    0.47             734755.76  proactive neutral methodology                    2
# Upgradable transitional data-warehouse         2023-06-29  2023-12-13  75569.28  0.59  social media  B2C              referral   0.67             558302.11  upgradable transitional data-warehouse           2
# User-friendly client-driven service-desk       2023-01-06  2023-12-11  36800.58  0.40  webinar       B2C              promotion  0.52             206241.46  user-friendly client-driven service-desk         2
# Name: count, dtype: int64

# %%
df_cleaned = df.drop_duplicates(subset=['campaign_name_lower', 'start_date', 'end_date', 'budget', 'roi', 'type',
                                        'target_audience', 'channel', 'conversion_rate', 'revenue'], keep='first')
num_dups = df.shape[0] - df_cleaned.shape[0]
print(f"{num_dups} perfect duplicate entries removed.")
# Out:
# 15 perfect duplicate entries removed.

# %%
df_cleaned['campaign_name_lower'].value_counts()
# Out:
# campaign_name_lower
# upgradable transitional data-warehouse      2
# reverse-engineered static infrastructure    2
# user-friendly client-driven service-desk    2
# public-key multi-tasking throughput         1
# inverse context-sensitive middleware        1
#                                            ..
# virtual methodical projection               1
# configurable 6thgeneration approach         1
# networked zero administration hardware      1
# integrated dedicated solution               1
# too many conversions                        1
# Name: count, Length: 1014, dtype: int64

# %%
# First, recompute value counts
campaign_dups = df_cleaned['campaign_name_lower'].value_counts()
remaining_dups = campaign_dups[campaign_dups > 1].index  # campaign names with >1 occurrence

# Filter the full DataFrame for those campaign names
partial_duplicates = df_cleaned[df_cleaned['campaign_name_lower'].isin(remaining_dups)]

# Display all associated columns
partial_duplicates.sort_values(by='campaign_name_lower')
# Out:
#                                  campaign_name start_date   end_date  \
# 203   Reverse-engineered static infrastructure 2023-07-26 2024-05-29
# 985   Reverse-engineered static infrastructure 2023-07-16 2023-08-07
# 5       Upgradable transitional data-warehouse 2023-06-29 2023-12-13
# 1003    Upgradable transitional data-warehouse 2023-06-29 2023-12-13
# 7     User-friendly client-driven service-desk 2023-01-06 2023-12-11
# 1004  User-friendly client-driven service-desk 2023-01-06 2023-12-11
#
#         budget   roi          type target_audience    channel  \
# 203   12246.32  0.48         email             B2B   referral
# 985    7315.35  0.86         email             B2C   referral
# 5     75569.28  0.59  social media             B2C   referral
# 1003       NaN  0.59  social media             B2C   referral
# 7     36800.58  0.40       webinar             B2C  promotion
# 1004  36800.58  0.40           NaN             B2C  promotion
#
#       conversion_rate    revenue                       campaign_name_lower
# 203              0.44  987205.29  reverse-engineered static infrastructure
# 985              0.70  162798.55  reverse-engineered static infrastructure
# 5                0.67  558302.11    upgradable transitional data-warehouse
# 1003             0.67  558302.11    upgradable transitional data-warehouse
# 7                0.52  206241.46  user-friendly client-driven service-desk
# 1004             0.52  206241.46  user-friendly client-driven service-desk

# %%
# Define group key to uniquely identify rows for merging
partial_key = ['campaign_name_lower', 'start_date', 'end_date']

# Columns that can have NaNs and should be merged
merge_columns = ['budget', 'roi', 'type', 'target_audience', 'channel', 'conversion_rate', 'revenue']

# Merge only within partial_duplicates
def merge_partial_group(group):
    merged = {}
    for col in merge_columns:
        non_nulls = group[col].dropna()
        merged[col] = non_nulls.iloc[0] if not non_nulls.empty else None
    # Retain key columns
    for col in partial_key:
        merged[col] = group[col].iloc[0]
    return pd.Series(merged)

# Apply to partial duplicates only
merged_partials = partial_duplicates.groupby(partial_key, as_index=False).apply(merge_partial_group)

# Combine with the rest of the cleaned data (excluding original partials)
rest_df = df_cleaned[~df_cleaned.index.isin(partial_duplicates.index)]
merged_df_final = pd.concat([rest_df, merged_partials], ignore_index=True)
# Out:
# /var/folders/hs/_zm07x3j45d2y84d2435ly2w0000gn/T/ipykernel_61237/2128183319.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   merged_partials = partial_duplicates.groupby(partial_key, as_index=False).apply(merge_partial_group)

# %%
print("Before:", len(df_cleaned))
print("After merging near-duplicates:", len(merged_df_final))
# Out:
# Before: 1017
# After merging near-duplicates: 1015

# %%
# First, recompute value counts
campaign_dups = merged_df_final['campaign_name_lower'].value_counts()
remaining_dups = campaign_dups[campaign_dups > 1].index  # campaign names with >1 occurrence

# Filter the full DataFrame for those campaign names
partial_duplicates = merged_df_final[merged_df_final['campaign_name_lower'].isin(remaining_dups)]

# Display all associated columns
partial_duplicates.sort_values(by='campaign_name_lower')
# Out:
#      campaign_name start_date   end_date    budget   roi   type  \
# 1011           NaN 2023-07-16 2023-08-07   7315.35  0.86  email
# 1012           NaN 2023-07-26 2024-05-29  12246.32  0.48  email
#
#      target_audience   channel  conversion_rate    revenue  \
# 1011             B2C  referral             0.70  162798.55
# 1012             B2B  referral             0.44  987205.29
#
#                            campaign_name_lower
# 1011  reverse-engineered static infrastructure
# 1012  reverse-engineered static infrastructure

# %%
merged_df_final.isnull().sum()
# Out:
# campaign_name          4
# start_date             3
# end_date               3
# budget                 3
# roi                    4
# type                   0
# target_audience        2
# channel                1
# conversion_rate        4
# revenue                3
# campaign_name_lower    0
# dtype: int64

# %%
merged_df_final = merged_df_final.drop(columns=['campaign_name'])
merged_df_final = merged_df_final.rename(columns={'campaign_name_lower': 'campaign_name'})

# %%
merged_df_final.head(5)
# Out:
#   start_date   end_date    budget   roi          type target_audience  \
# 0 2023-04-01 2024-02-23   8082.30  0.35         email             B2B
# 1 2023-02-15 2024-04-22  17712.98  0.74         email             B2C
# 2 2022-12-20 2023-10-11  84643.10  0.37       podcast             B2B
# 3 2022-09-26 2023-09-27  14589.75  0.47       webinar             B2B
# 4 2023-07-07 2024-05-15  39291.90  0.30  social media             B2B
#
#      channel  conversion_rate    revenue  \
# 0    organic             0.40  709593.48
# 1  promotion             0.66  516609.10
# 2       paid             0.28  458227.42
# 3    organic             0.19   89958.73
# 4  promotion             0.81   47511.35
#
#                                    campaign_name
# 0            public-key multi-tasking throughput
# 1             de-engineered analyzing task-force
# 2  balanced solution-oriented local area network
# 3              distributed real-time methodology
# 4            front-line executive infrastructure

# %%
merged_df_final.isnull().sum()
# Out:
# start_date         3
# end_date           3
# budget             3
# roi                4
# type               0
# target_audience    2
# channel            1
# conversion_rate    4
# revenue            3
# campaign_name      0
# dtype: int64

# %%
print("🎯 Channel Distribution:")
print(merged_df_final['channel'].value_counts(dropna=False))
print("\n")

print("👥 Target Audience Distribution:")
print(merged_df_final['target_audience'].value_counts(dropna=False))
print("\n")

print("📢 Campaign Type Distribution:")
print(merged_df_final['type'].value_counts(dropna=False))
# Out:
# 🎯 Channel Distribution:
# channel
# promotion    275
# referral     253
# organic      245
# paid         241
# NaN            1
# Name: count, dtype: int64
#
#
# 👥 Target Audience Distribution:
# target_audience
# B2B             520
# B2C             492
# NaN               2
# social media      1
# Name: count, dtype: int64
#
#
# 📢 Campaign Type Distribution:
# type
# email           284
# webinar         264
# social media    235
# podcast         230
# event             1
# B2B               1
# Name: count, dtype: int64

# %%
merged_df_final[['budget', 'revenue', 'roi', 'conversion_rate']].isnull().sum()
# Out:
# budget             3
# revenue            3
# roi                4
# conversion_rate    4
# dtype: int64

# %%
merged_df_final['budget'] = merged_df_final['budget'].fillna(0)
merged_df_final['revenue'] = merged_df_final['revenue'].fillna(0)

# %%
# Fill ROI with 0 where budget == 0 and revenue == 0
mask_roi = (merged_df_final['budget'] == 0) & (merged_df_final['revenue'] == 0)
merged_df_final.loc[mask_roi, 'roi'] = merged_df_final.loc[mask_roi, 'roi'].fillna(0)

# Fill conversion_rate with 0 using the same logic
merged_df_final.loc[mask_roi, 'conversion_rate'] = merged_df_final.loc[mask_roi, 'conversion_rate'].fillna(0)

# %%
merged_df_final[['budget', 'revenue', 'roi', 'conversion_rate']].isnull().sum()
# Out:
# budget             0
# revenue            0
# roi                3
# conversion_rate    3
# dtype: int64

# %%
# Fill ROI where it's NaN and both budget and revenue are present and budget > 0
mask = merged_df_final['roi'].isnull() & \
       merged_df_final['budget'].notnull() & \
       merged_df_final['revenue'].notnull() & \
       (merged_df_final['budget'] > 0)

merged_df_final.loc[mask, 'roi'] = (
    merged_df_final.loc[mask, 'revenue'] / merged_df_final.loc[mask, 'budget']
)
print("Remaining nulls in ROI:", merged_df_final['roi'].isnull().sum())
# Out:
# Remaining nulls in ROI: 1

# %%
merged_df_final.loc[merged_df_final['roi'].isnull(), ['campaign_name', 'budget', 'revenue', 'roi']]
# Out:
#        campaign_name  budget  revenue  roi
# 1008  invalid budget     0.0  50000.0  NaN

# %%
merged_df_final.isnull().sum()
# Out:
# start_date         3
# end_date           3
# budget             0
# roi                1
# type               0
# target_audience    2
# channel            1
# conversion_rate    3
# revenue            0
# campaign_name      0
# dtype: int64

# %%
mask_conv_zero = (merged_df_final['conversion_rate'].isnull()) & \
                 (merged_df_final['budget'] == 0) & \
                 (merged_df_final['revenue'] == 0)

merged_df_final.loc[mask_conv_zero, 'conversion_rate'] = 0

# %%
missing_conversion = merged_df_final[merged_df_final['conversion_rate'].isnull()]
print(missing_conversion[['campaign_name', 'budget', 'revenue', 'conversion_rate']])
# Out:
#                       campaign_name    budget   revenue  conversion_rate
# 996   new campaign - missing budget       0.0   45000.0              NaN
# 1001           broken-date campaign   25000.0   87500.0              NaN
# 1007                    random mess  100000.0  300000.0              NaN

# %%
merged_df_final['conversion_flag'] = None

# Flag rows where conversion_rate is NaN, but budget is 0 and revenue > 0
anomaly_mask = (
    merged_df_final['conversion_rate'].isnull() &
    (merged_df_final['budget'] == 0) &
    (merged_df_final['revenue'] > 0)
)

merged_df_final.loc[anomaly_mask, 'conversion_flag'] = 'Undefined (zero budget + revenue)'

# %%
merged_df_final.isnull().sum()
# Out:
# start_date            3
# end_date              3
# budget                0
# roi                   1
# type                  0
# target_audience       2
# channel               1
# conversion_rate       3
# revenue               0
# campaign_name         0
# conversion_flag    1014
# dtype: int64

# %%
merged_df_final.head(5)
# Out:
#   start_date   end_date    budget   roi          type target_audience  \
# 0 2023-04-01 2024-02-23   8082.30  0.35         email             B2B
# 1 2023-02-15 2024-04-22  17712.98  0.74         email             B2C
# 2 2022-12-20 2023-10-11  84643.10  0.37       podcast             B2B
# 3 2022-09-26 2023-09-27  14589.75  0.47       webinar             B2B
# 4 2023-07-07 2024-05-15  39291.90  0.30  social media             B2B
#
#      channel  conversion_rate    revenue  \
# 0    organic             0.40  709593.48
# 1  promotion             0.66  516609.10
# 2       paid             0.28  458227.42
# 3    organic             0.19   89958.73
# 4  promotion             0.81   47511.35
#
#                                    campaign_name conversion_flag
# 0            public-key multi-tasking throughput            None
# 1             de-engineered analyzing task-force            None
# 2  balanced solution-oriented local area network            None
# 3              distributed real-time methodology            None
# 4            front-line executive infrastructure            None

# %%
missing_cat_info = merged_df_final[
    merged_df_final['target_audience'].isnull() |
    merged_df_final['channel'].isnull()
]

# Show everything
missing_cat_info
# Out:
#      start_date   end_date    budget   roi     type target_audience   channel  \
# 1003 2023-01-01        NaT       0.0  0.00      B2B    social media       NaN
# 1005 2023-04-15 2023-09-15   30000.0  0.25    email             NaN      paid
# 1007 2023-06-06        NaT  100000.0  3.00  podcast             NaN  referral
#
#       conversion_rate   revenue                  campaign_name conversion_flag
# 1003              0.0       0.0            null-heavy campaign            None
# 1005              0.4   45000.0  extra long name campaign test            None
# 1007              NaN  300000.0                    random mess            None

# %%
# Filter to only social media campaigns
social_media_campaigns = merged_df_final[merged_df_final['type'] == 'social media']

# Count values in 'channel' and 'target_audience'
channel_counts = social_media_campaigns['channel'].value_counts(dropna=False)
audience_counts = social_media_campaigns['target_audience'].value_counts(dropna=False)

print("📡 Channels used in social media campaigns:\n", channel_counts)
print("\n🎯 Target audiences in social media campaigns:\n", audience_counts)
# Out:
# 📡 Channels used in social media campaigns:
#  channel
# paid         64
# organic      62
# promotion    55
# referral     54
# Name: count, dtype: int64
#
# 🎯 Target audiences in social media campaigns:
#  target_audience
# B2B    126
# B2C    109
# Name: count, dtype: int64

# %%
# Filter for social media campaign types
social_media_campaigns = merged_df_final[merged_df_final['type'] == 'social media']

# Group by channel and target_audience, then count
grouped_counts = social_media_campaigns.groupby(['channel', 'target_audience']).size().reset_index(name='count')

# Display the result
grouped_counts
# Out:
#      channel target_audience  count
# 0    organic             B2B     34
# 1    organic             B2C     28
# 2       paid             B2B     32
# 3       paid             B2C     32
# 4  promotion             B2B     32
# 5  promotion             B2C     23
# 6   referral             B2B     28
# 7   referral             B2C     26

# %%
merged_df_final['missing_channel_flag'] = merged_df_final['channel'].isnull()
merged_df_final['missing_audience_flag'] = merged_df_final['target_audience'].isnull()

# %%
# Fill NaN with empty string ONLY in object (string-like) columns
for col in merged_df_final.select_dtypes(include='object').columns:
    merged_df_final[col] = merged_df_final[col].fillna("")

# %%
merged_df_final.isnull().sum()
# Out:
# start_date               3
# end_date                 3
# budget                   0
# roi                      1
# type                     0
# target_audience          0
# channel                  0
# conversion_rate          3
# revenue                  0
# campaign_name            0
# conversion_flag          0
# missing_channel_flag     0
# missing_audience_flag    0
# dtype: int64

# %%
missing_dates = merged_df_final[
    merged_df_final['start_date'].isnull() | merged_df_final['end_date'].isnull()
]

missing_dates
# Out:
#      start_date   end_date    budget   roi     type target_audience  \
# 997         NaT        NaT   50000.0  0.65  webinar             B2C
# 1000        NaT 2023-12-31   50000.0  2.40    event             B2C
# 1001        NaT 2024-01-01   25000.0  0.45    email             B2B
# 1003 2023-01-01        NaT       0.0  0.00      B2B    social media
# 1007 2023-06-06        NaT  100000.0  3.00  podcast
#
#         channel  conversion_rate   revenue                  campaign_name  \
# 997   promotion              0.9  320000.0                   typo in date
# 1000       paid              0.3  120000.0  cloud-based scalable solution
# 1001    organic              NaN   87500.0           broken-date campaign
# 1003                         0.0       0.0            null-heavy campaign
# 1007   referral              NaN  300000.0                    random mess
#
#      conversion_flag  missing_channel_flag  missing_audience_flag  \
# 997                                  False                  False
# 1000                                 False                  False
# 1001                                 False                  False
# 1003                                  True                  False
# 1007                                 False                   True
#
#                                             date_flag
# 997   Invalid campaign (unparseable or missing dates)
# 1000                                             None
# 1001                                             None
# 1003                                             None
# 1007                                             None

# %%
# Make sure there's a flag column
merged_df_final['date_flag'] = merged_df_final.get('date_flag', None)

# Flag rows with both dates missing
both_missing = merged_df_final['start_date'].isnull() & merged_df_final['end_date'].isnull()
merged_df_final.loc[both_missing, 'date_flag'] = "Invalid campaign (unparseable or missing dates)"

# %%
metrics = ['budget', 'roi', 'conversion_rate', 'revenue']

# Build mask: all 4 values must be 0.0
all_zero_mask = (merged_df_final[metrics] == 0).all(axis=1)

# Drop them
merged_df_final = merged_df_final[~all_zero_mask].reset_index(drop=True)

# %%
missing_dates = merged_df_final[
    merged_df_final['start_date'].isnull() | merged_df_final['end_date'].isnull()
]

missing_dates
# Out:
#      start_date   end_date    budget   roi     type target_audience  \
# 997         NaT        NaT   50000.0  0.65  webinar             B2C
# 1000        NaT 2023-12-31   50000.0  2.40    event             B2C
# 1001        NaT 2024-01-01   25000.0  0.45    email             B2B
# 1006 2023-06-06        NaT  100000.0  3.00  podcast
#
#         channel  conversion_rate   revenue                  campaign_name  \
# 997   promotion              0.9  320000.0                   typo in date
# 1000       paid              0.3  120000.0  cloud-based scalable solution
# 1001    organic              NaN   87500.0           broken-date campaign
# 1006   referral              NaN  300000.0                    random mess
#
#      conversion_flag  missing_channel_flag  missing_audience_flag  \
# 997                                  False                  False
# 1000                                 False                  False
# 1001                                 False                  False
# 1006                                 False                   True
#
#                                             date_flag
# 997   Invalid campaign (unparseable or missing dates)
# 1000                                             None
# 1001                                             None
# 1006                                             None

# %%
# Get dataset boundaries
earliest_start = merged_df_final['start_date'].min()
latest_end = merged_df_final['end_date'].max()

# %%
both_missing_mask = merged_df_final['date_flag'] == "Invalid campaign (unparseable or missing dates)"

merged_df_final.loc[both_missing_mask, 'start_date'] = earliest_start
merged_df_final.loc[both_missing_mask, 'end_date'] = latest_end

# %%
missing_dates = merged_df_final[
    merged_df_final['start_date'].isnull() | merged_df_final['end_date'].isnull()
]

missing_dates
# Out:
#      start_date   end_date    budget   roi     type target_audience   channel  \
# 1000        NaT 2023-12-31   50000.0  2.40    event             B2C      paid
# 1001        NaT 2024-01-01   25000.0  0.45    email             B2B   organic
# 1006 2023-06-06        NaT  100000.0  3.00  podcast                  referral
#
#       conversion_rate   revenue                  campaign_name  \
# 1000              0.3  120000.0  cloud-based scalable solution
# 1001              NaN   87500.0           broken-date campaign
# 1006              NaN  300000.0                    random mess
#
#      conversion_flag  missing_channel_flag  missing_audience_flag date_flag
# 1000                                 False                  False      None
# 1001                                 False                  False      None
# 1006                                 False                   True      None

# %%
# Find all rows where both are NaT
both_missing_mask = merged_df_final['start_date'].isnull() | merged_df_final['end_date'].isnull()

# Fill both values
merged_df_final.loc[both_missing_mask, 'start_date'] = earliest_start
merged_df_final.loc[both_missing_mask, 'end_date'] = latest_end

# %%
merged_df_final[['start_date', 'end_date']].isnull().sum()
# Out:
# start_date    0
# end_date      0
# dtype: int64

# %%
merged_df_final.isnull().sum()
# Out:
# start_date                  0
# end_date                    0
# budget                      0
# roi                         1
# type                        0
# target_audience             0
# channel                     0
# conversion_rate             3
# revenue                     0
# campaign_name               0
# conversion_flag             0
# missing_channel_flag        0
# missing_audience_flag       0
# date_flag                1013
# dtype: int64

# %%
negatives = merged_df_final[
    (merged_df_final['budget'] < 0) |
    (merged_df_final['revenue'] < 0) |
    (merged_df_final['roi'] < 0) |
    (merged_df_final['conversion_rate'] < 0)
]
negatives
# Out:
#      start_date   end_date   budget  roi     type target_audience   channel  \
# 1002 2022-10-10 2023-05-05 -10000.0 -0.2  podcast             B2C  referral
#
#       conversion_rate  revenue      campaign_name conversion_flag  \
# 1002              0.1      0.0  negative roi test
#
#       missing_channel_flag  missing_audience_flag date_flag
# 1002                 False                  False      None

# %%
merged_df_final.loc[merged_df_final['budget'] < 0, 'budget_flag'] = 'Negative value corrected to 0'

# %%
merged_df_final.loc[merged_df_final['budget'] < 0, 'budget'] = 0

# %%
neg_roi_mask = merged_df_final['roi'] < 0
merged_df_final.loc[neg_roi_mask, 'roi_flag'] = 'Negative ROI corrected to 0'
merged_df_final.loc[neg_roi_mask, 'roi'] = 0

# %%
negatives = merged_df_final[
    (merged_df_final['budget'] < 0) |
    (merged_df_final['revenue'] < 0) |
    (merged_df_final['roi'] < 0) |
    (merged_df_final['conversion_rate'] < 0)
]
negatives
# Out:
# Empty DataFrame
# Columns: [start_date, end_date, budget, roi, type, target_audience, channel, conversion_rate, revenue, campaign_name, conversion_flag, missing_channel_flag, missing_audience_flag, date_flag, budget_flag, roi_flag]
# Index: []

# %%
print("📢 Campaign Type Counts:")
print(merged_df_final['target_audience'].value_counts(dropna=False))
print("\n")

print("📡 Channel Counts:")
print(merged_df_final['channel'].value_counts(dropna=False))
# Out:
# 📢 Campaign Type Counts:
# target_audience
# B2B          520
# B2C          492
# B2B & B2C      2
# Name: count, dtype: int64
#
#
# 📡 Channel Counts:
# channel
# promotion    275
# referral     253
# organic      245
# paid         241
# Name: count, dtype: int64

# %%
merged_df_final['target_audience'] = merged_df_final['target_audience'].replace('', 'B2B & B2C')

# %%
merged_df_final[['budget', 'revenue']].describe()
# Out:
#              budget        revenue
# count   1014.000000    1014.000000
# mean   49411.861266  512540.753277
# std    28927.456577  288277.620086
# min        0.000000       0.000000
# 25%    24811.427500  267999.680000
# 50%    47197.385000  519718.345000
# 75%    74887.827500  770016.185000
# max    99340.977600  990888.155700

# %%
merged_df_final[['budget', 'revenue']].quantile([0.90, 0.95, 0.99])
# Out:
#           budget      revenue
# 0.90  89808.2000  904875.3630
# 0.95  95273.2145  950440.0570
# 0.99  99340.9776  990888.1557

# %%
merged_df_final.loc[merged_df_final['budget'] > 1_000_000, 'budget_flag'] = 'Suspiciously high (outlier)'
merged_df_final.loc[merged_df_final['revenue'] > 1_000_000, 'revenue_flag'] = 'Suspiciously high (outlier)'

# %%
budget_cap = merged_df_final['budget'].quantile(0.99)
revenue_cap = merged_df_final['revenue'].quantile(0.99)

merged_df_final['budget'] = merged_df_final['budget'].clip(upper=budget_cap)
merged_df_final['revenue'] = merged_df_final['revenue'].clip(upper=revenue_cap)

# %%
merged_df_final['net_profit'] = merged_df_final['revenue'] - merged_df_final['budget']

# %%
merged_df_final[['campaign_name', 'budget', 'revenue', 'net_profit']].head()
# Out:
#                                    campaign_name    budget    revenue  \
# 0            public-key multi-tasking throughput   8082.30  709593.48
# 1             de-engineered analyzing task-force  17712.98  516609.10
# 2  balanced solution-oriented local area network  84643.10  458227.42
# 3              distributed real-time methodology  14589.75   89958.73
# 4            front-line executive infrastructure  39291.90   47511.35
#
#    net_profit
# 0   701511.18
# 1   498896.12
# 2   373584.32
# 3    75368.98
# 4     8219.45

# %%
negative_profit_campaigns = merged_df_final[merged_df_final['net_profit'] < 0]
negative_profit_campaigns
# Out:
#      start_date   end_date      budget   roi          type target_audience  \
# 12   2022-11-05 2023-09-05  36848.3000  0.92       webinar             B2C
# 22   2022-08-26 2024-07-24  48366.5000  0.21  social media             B2B
# 26   2022-11-18 2023-10-05  99340.9776  0.63         email             B2B
# 58   2023-06-23 2024-01-03  79220.8000  0.60  social media             B2C
# 81   2023-02-22 2024-02-18  52125.2000  0.16       webinar             B2C
# 200  2022-11-09 2024-01-28  91490.9200  0.93       webinar             B2C
# 237  2023-05-18 2023-08-24  78742.3900  0.81  social media             B2C
# 253  2022-11-07 2024-01-19  85249.4700  0.97  social media             B2B
# 264  2023-03-18 2024-06-29  93497.4000  0.44         email             B2B
# 266  2023-04-09 2023-10-02  63250.9100  0.72         email             B2C
# 277  2023-02-05 2024-06-03  96380.6500  0.99         email             B2B
# 292  2022-08-31 2024-02-17  73723.4000  0.74       webinar             B2C
# 327  2022-10-23 2023-08-15  99340.9776  0.80         email             B2C
# 381  2023-01-17 2023-12-22  16485.7200  0.89       podcast             B2B
# 412  2023-04-12 2024-02-27  92072.4100  0.48         email             B2B
# 424  2022-09-24 2023-11-12  11006.3000  0.25       podcast             B2C
# 455  2023-04-26 2023-10-12  86716.3800  0.74         email             B2B
# 523  2023-06-08 2023-08-02  67475.3500  0.50         email             B2B
# 554  2022-11-25 2024-04-21  74431.6700  0.85         email             B2B
# 582  2023-04-01 2024-02-26  58942.7700  0.62       webinar             B2B
# 599  2022-09-02 2024-04-22  87665.6000  0.51       podcast             B2B
# 612  2023-05-10 2023-12-09  17355.9800  0.74  social media             B2B
# 633  2023-03-06 2023-09-09  82065.3900  0.81       webinar             B2C
# 659  2023-04-25 2024-07-24  49206.4300  0.15       webinar             B2B
# 666  2022-12-18 2023-12-22  85026.2700  0.17       webinar             B2C
# 689  2023-02-03 2024-07-18  80301.8600  0.43       podcast             B2B
# 707  2022-09-16 2024-05-08  99340.9776  0.23         email             B2C
# 710  2023-07-22 2024-03-23  84628.7900  0.38       webinar             B2B
# 756  2022-09-27 2024-03-26  95256.1900  0.54       podcast             B2C
# 775  2023-06-13 2024-04-26  76484.1100  0.88       podcast             B2B
# 779  2023-01-25 2023-08-16  50624.2400  0.13       webinar             B2C
# 818  2023-07-10 2024-05-16  37054.1600  0.39         email             B2B
# 837  2023-06-03 2024-03-09  79189.2000  0.81       webinar             B2B
# 842  2022-11-16 2024-04-10  23030.5100  0.40  social media             B2C
# 858  2023-06-11 2024-07-17  84718.2500  0.98  social media             B2B
# 886  2023-02-16 2023-08-19  61978.1000  0.39  social media             B2C
# 893  2023-07-04 2024-05-30  32993.6100  0.40         email             B2B
# 909  2022-11-22 2023-10-21  80176.5000  0.46         email             B2C
# 944  2022-11-10 2024-05-06  72633.7500  0.42         email             B2C
# 972  2023-07-07 2023-08-18  69815.8200  0.16       podcast             B2C
# 979  2023-03-07 2024-04-30  80292.7000  0.60       webinar             B2B
# 999  2023-07-01 2024-03-01  99340.9776  0.10         email             B2B
# 1005 2023-02-01 2023-08-01  20000.0000  0.30  social media             B2B
#
#         channel  conversion_rate   revenue  \
# 12     referral             0.10   4190.95
# 22    promotion             0.87  41004.95
# 26      organic             0.18  14073.59
# 58         paid             0.30  29575.48
# 81     referral             0.80  27754.76
# 200    referral             0.95  38601.99
# 237    referral             0.79  10253.30
# 253        paid             0.90  34642.19
# 264   promotion             0.37  58328.00
# 266        paid             0.76  32045.66
# 277    referral             0.18  35031.43
# 292   promotion             0.21  62558.41
# 327   promotion             0.91   8272.50
# 381    referral             0.41   9714.17
# 412     organic             0.54   8811.92
# 424   promotion             0.98   3641.30
# 455        paid             0.95  69360.86
# 523   promotion             0.22  53555.95
# 554   promotion             0.52  20979.33
# 582   promotion             0.36  21603.20
# 599   promotion             0.56  10257.40
# 612    referral             0.48   9695.94
# 633    referral             0.24  52944.00
# 659   promotion             0.18  33048.36
# 666        paid             0.78  37752.49
# 689   promotion             0.73  77385.32
# 707    referral             0.70   7622.28
# 710     organic             0.18  27207.72
# 756    referral             0.65  84562.94
# 775        paid             0.41  24367.21
# 779    referral             0.58  14079.60
# 818    referral             0.60   5971.96
# 837    referral             0.15   9576.39
# 842    referral             0.90  14158.69
# 858        paid             0.97  76971.76
# 886        paid             0.77    108.21
# 893   promotion             0.90  15015.31
# 909   promotion             0.11  24198.61
# 944    referral             0.19  46016.24
# 972     organic             0.27   2810.51
# 979    referral             0.25  19497.73
# 999   promotion             0.20  50000.00
# 1005    organic             0.50      0.00
#
#                                       campaign_name conversion_flag  \
# 12                  innovative web-enabled function
# 22                horizontal hybrid instruction set
# 26                  seamless clear-thinking product
# 58                persevering web-enabled workforce
# 81           reverse-engineered foreground approach
# 200            focused responsive open architecture
# 237               decentralized incremental synergy
# 253                     grass-roots reciprocal core
# 264    re-contextualized regional pricing structure
# 266                 reactive client-driven paradigm
# 277                automated 5thgeneration attitude
# 292                         reduced mobile matrices
# 327                     persistent radical approach
# 381            programmable asynchronous encryption
# 412                  reduced high-level methodology
# 424             programmable homogeneous projection
# 455                   customizable global hierarchy
# 523                   persevering tangible hardware
# 554               proactive bifurcated architecture
# 582   realigned responsive graphical user interface
# 599           multi-lateral 6thgeneration benchmark
# 612          grass-roots asynchronous knowledgebase
# 633           enterprise-wide non-volatile hardware
# 659      decentralized multimedia open architecture
# 666                         universal 24/7 strategy
# 689      user-friendly encompassing functionalities
# 707               horizontal asymmetric contingency
# 710      synergized mission-critical conglomeration
# 756            right-sized next generation solution
# 775                face-to-face scalable definition
# 779              polarized client-driven moratorium
# 818                  universal uniform service-desk
# 837                        compatible local concept
# 842              down-sized object-oriented website
# 858           multi-lateral grid-enabled middleware
# 886                  grass-roots scalable framework
# 893           enterprise-wide tangible secured line
# 909            de-engineered static standardization
# 944      reverse-engineered regional data-warehouse
# 972                     extended 24hour contingency
# 979                   universal asymmetric extranet
# 999                                  outlier budget
# 1005                            no revenue campaign
#
#       missing_channel_flag  missing_audience_flag date_flag  \
# 12                   False                  False      None
# 22                   False                  False      None
# 26                   False                  False      None
# 58                   False                  False      None
# 81                   False                  False      None
# 200                  False                  False      None
# 237                  False                  False      None
# 253                  False                  False      None
# 264                  False                  False      None
# 266                  False                  False      None
# 277                  False                  False      None
# 292                  False                  False      None
# 327                  False                  False      None
# 381                  False                  False      None
# 412                  False                  False      None
# 424                  False                  False      None
# 455                  False                  False      None
# 523                  False                  False      None
# 554                  False                  False      None
# 582                  False                  False      None
# 599                  False                  False      None
# 612                  False                  False      None
# 633                  False                  False      None
# 659                  False                  False      None
# 666                  False                  False      None
# 689                  False                  False      None
# 707                  False                  False      None
# 710                  False                  False      None
# 756                  False                  False      None
# 775                  False                  False      None
# 779                  False                  False      None
# 818                  False                  False      None
# 837                  False                  False      None
# 842                  False                  False      None
# 858                  False                  False      None
# 886                  False                  False      None
# 893                  False                  False      None
# 909                  False                  False      None
# 944                  False                  False      None
# 972                  False                  False      None
# 979                  False                  False      None
# 999                  False                  False      None
# 1005                 False                  False      None
#
#                       budget_flag roi_flag revenue_flag  net_profit
# 12                           None     None         None -32657.3500
# 22                           None     None         None  -7361.5500
# 26                           None     None         None -85267.3876
# 58                           None     None         None -49645.3200
# 81                           None     None         None -24370.4400
# 200                          None     None         None -52888.9300
# 237                          None     None         None -68489.0900
# 253                          None     None         None -50607.2800
# 264                          None     None         None -35169.4000
# 266                          None     None         None -31205.2500
# 277                          None     None         None -61349.2200
# 292                          None     None         None -11164.9900
# 327                          None     None         None -91068.4776
# 381                          None     None         None  -6771.5500
# 412                          None     None         None -83260.4900
# 424                          None     None         None  -7365.0000
# 455                          None     None         None -17355.5200
# 523                          None     None         None -13919.4000
# 554                          None     None         None -53452.3400
# 582                          None     None         None -37339.5700
# 599                          None     None         None -77408.2000
# 612                          None     None         None  -7660.0400
# 633                          None     None         None -29121.3900
# 659                          None     None         None -16158.0700
# 666                          None     None         None -47273.7800
# 689                          None     None         None  -2916.5400
# 707                          None     None         None -91718.6976
# 710                          None     None         None -57421.0700
# 756                          None     None         None -10693.2500
# 775                          None     None         None -52116.9000
# 779                          None     None         None -36544.6400
# 818                          None     None         None -31082.2000
# 837                          None     None         None -69612.8100
# 842                          None     None         None  -8871.8200
# 858                          None     None         None  -7746.4900
# 886                          None     None         None -61869.8900
# 893                          None     None         None -17978.3000
# 909                          None     None         None -55977.8900
# 944                          None     None         None -26617.5100
# 972                          None     None         None -67005.3100
# 979                          None     None         None -60794.9700
# 999   Suspiciously high (outlier)     None         None -49340.9776
# 1005                         None     None         None -20000.0000

# %%
merged_df_final.isnull().sum()
# Out:
# start_date                  0
# end_date                    0
# budget                      0
# roi                         1
# type                        0
# target_audience             0
# channel                     0
# conversion_rate             3
# revenue                     0
# campaign_name               0
# conversion_flag             0
# missing_channel_flag        0
# missing_audience_flag       0
# date_flag                1013
# budget_flag              1012
# roi_flag                 1013
# revenue_flag             1014
# net_profit                  0
# dtype: int64

# %%
flag_cols = ['date_flag', 'budget_flag', 'roi_flag', 'revenue_flag']

for col in flag_cols:
    merged_df_final[col] = merged_df_final[col].where(merged_df_final[col].notnull(), 'False')

# %%
merged_df_final['net_profit'].describe()
# Out:
# count      1014.000000
# mean     463128.892011
# std      290036.454299
# min      -91718.697600
# 25%      216065.790000
# 50%      472980.420000
# 75%      712656.545000
# max      987859.730000
# Name: net_profit, dtype: float64

# %%
merged_df_final[merged_df_final['net_profit'] < 0]
# Out:
#      start_date   end_date      budget   roi          type target_audience  \
# 12   2022-11-05 2023-09-05  36848.3000  0.92       webinar             B2C
# 22   2022-08-26 2024-07-24  48366.5000  0.21  social media             B2B
# 26   2022-11-18 2023-10-05  99340.9776  0.63         email             B2B
# 58   2023-06-23 2024-01-03  79220.8000  0.60  social media             B2C
# 81   2023-02-22 2024-02-18  52125.2000  0.16       webinar             B2C
# 200  2022-11-09 2024-01-28  91490.9200  0.93       webinar             B2C
# 237  2023-05-18 2023-08-24  78742.3900  0.81  social media             B2C
# 253  2022-11-07 2024-01-19  85249.4700  0.97  social media             B2B
# 264  2023-03-18 2024-06-29  93497.4000  0.44         email             B2B
# 266  2023-04-09 2023-10-02  63250.9100  0.72         email             B2C
# 277  2023-02-05 2024-06-03  96380.6500  0.99         email             B2B
# 292  2022-08-31 2024-02-17  73723.4000  0.74       webinar             B2C
# 327  2022-10-23 2023-08-15  99340.9776  0.80         email             B2C
# 381  2023-01-17 2023-12-22  16485.7200  0.89       podcast             B2B
# 412  2023-04-12 2024-02-27  92072.4100  0.48         email             B2B
# 424  2022-09-24 2023-11-12  11006.3000  0.25       podcast             B2C
# 455  2023-04-26 2023-10-12  86716.3800  0.74         email             B2B
# 523  2023-06-08 2023-08-02  67475.3500  0.50         email             B2B
# 554  2022-11-25 2024-04-21  74431.6700  0.85         email             B2B
# 582  2023-04-01 2024-02-26  58942.7700  0.62       webinar             B2B
# 599  2022-09-02 2024-04-22  87665.6000  0.51       podcast             B2B
# 612  2023-05-10 2023-12-09  17355.9800  0.74  social media             B2B
# 633  2023-03-06 2023-09-09  82065.3900  0.81       webinar             B2C
# 659  2023-04-25 2024-07-24  49206.4300  0.15       webinar             B2B
# 666  2022-12-18 2023-12-22  85026.2700  0.17       webinar             B2C
# 689  2023-02-03 2024-07-18  80301.8600  0.43       podcast             B2B
# 707  2022-09-16 2024-05-08  99340.9776  0.23         email             B2C
# 710  2023-07-22 2024-03-23  84628.7900  0.38       webinar             B2B
# 756  2022-09-27 2024-03-26  95256.1900  0.54       podcast             B2C
# 775  2023-06-13 2024-04-26  76484.1100  0.88       podcast             B2B
# 779  2023-01-25 2023-08-16  50624.2400  0.13       webinar             B2C
# 818  2023-07-10 2024-05-16  37054.1600  0.39         email             B2B
# 837  2023-06-03 2024-03-09  79189.2000  0.81       webinar             B2B
# 842  2022-11-16 2024-04-10  23030.5100  0.40  social media             B2C
# 858  2023-06-11 2024-07-17  84718.2500  0.98  social media             B2B
# 886  2023-02-16 2023-08-19  61978.1000  0.39  social media             B2C
# 893  2023-07-04 2024-05-30  32993.6100  0.40         email             B2B
# 909  2022-11-22 2023-10-21  80176.5000  0.46         email             B2C
# 944  2022-11-10 2024-05-06  72633.7500  0.42         email             B2C
# 972  2023-07-07 2023-08-18  69815.8200  0.16       podcast             B2C
# 979  2023-03-07 2024-04-30  80292.7000  0.60       webinar             B2B
# 999  2023-07-01 2024-03-01  99340.9776  0.10         email             B2B
# 1005 2023-02-01 2023-08-01  20000.0000  0.30  social media             B2B
#
#         channel  conversion_rate   revenue  \
# 12     referral             0.10   4190.95
# 22    promotion             0.87  41004.95
# 26      organic             0.18  14073.59
# 58         paid             0.30  29575.48
# 81     referral             0.80  27754.76
# 200    referral             0.95  38601.99
# 237    referral             0.79  10253.30
# 253        paid             0.90  34642.19
# 264   promotion             0.37  58328.00
# 266        paid             0.76  32045.66
# 277    referral             0.18  35031.43
# 292   promotion             0.21  62558.41
# 327   promotion             0.91   8272.50
# 381    referral             0.41   9714.17
# 412     organic             0.54   8811.92
# 424   promotion             0.98   3641.30
# 455        paid             0.95  69360.86
# 523   promotion             0.22  53555.95
# 554   promotion             0.52  20979.33
# 582   promotion             0.36  21603.20
# 599   promotion             0.56  10257.40
# 612    referral             0.48   9695.94
# 633    referral             0.24  52944.00
# 659   promotion             0.18  33048.36
# 666        paid             0.78  37752.49
# 689   promotion             0.73  77385.32
# 707    referral             0.70   7622.28
# 710     organic             0.18  27207.72
# 756    referral             0.65  84562.94
# 775        paid             0.41  24367.21
# 779    referral             0.58  14079.60
# 818    referral             0.60   5971.96
# 837    referral             0.15   9576.39
# 842    referral             0.90  14158.69
# 858        paid             0.97  76971.76
# 886        paid             0.77    108.21
# 893   promotion             0.90  15015.31
# 909   promotion             0.11  24198.61
# 944    referral             0.19  46016.24
# 972     organic             0.27   2810.51
# 979    referral             0.25  19497.73
# 999   promotion             0.20  50000.00
# 1005    organic             0.50      0.00
#
#                                       campaign_name conversion_flag  \
# 12                  innovative web-enabled function
# 22                horizontal hybrid instruction set
# 26                  seamless clear-thinking product
# 58                persevering web-enabled workforce
# 81           reverse-engineered foreground approach
# 200            focused responsive open architecture
# 237               decentralized incremental synergy
# 253                     grass-roots reciprocal core
# 264    re-contextualized regional pricing structure
# 266                 reactive client-driven paradigm
# 277                automated 5thgeneration attitude
# 292                         reduced mobile matrices
# 327                     persistent radical approach
# 381            programmable asynchronous encryption
# 412                  reduced high-level methodology
# 424             programmable homogeneous projection
# 455                   customizable global hierarchy
# 523                   persevering tangible hardware
# 554               proactive bifurcated architecture
# 582   realigned responsive graphical user interface
# 599           multi-lateral 6thgeneration benchmark
# 612          grass-roots asynchronous knowledgebase
# 633           enterprise-wide non-volatile hardware
# 659      decentralized multimedia open architecture
# 666                         universal 24/7 strategy
# 689      user-friendly encompassing functionalities
# 707               horizontal asymmetric contingency
# 710      synergized mission-critical conglomeration
# 756            right-sized next generation solution
# 775                face-to-face scalable definition
# 779              polarized client-driven moratorium
# 818                  universal uniform service-desk
# 837                        compatible local concept
# 842              down-sized object-oriented website
# 858           multi-lateral grid-enabled middleware
# 886                  grass-roots scalable framework
# 893           enterprise-wide tangible secured line
# 909            de-engineered static standardization
# 944      reverse-engineered regional data-warehouse
# 972                     extended 24hour contingency
# 979                   universal asymmetric extranet
# 999                                  outlier budget
# 1005                            no revenue campaign
#
#       missing_channel_flag  missing_audience_flag date_flag  \
# 12                   False                  False     False
# 22                   False                  False     False
# 26                   False                  False     False
# 58                   False                  False     False
# 81                   False                  False     False
# 200                  False                  False     False
# 237                  False                  False     False
# 253                  False                  False     False
# 264                  False                  False     False
# 266                  False                  False     False
# 277                  False                  False     False
# 292                  False                  False     False
# 327                  False                  False     False
# 381                  False                  False     False
# 412                  False                  False     False
# 424                  False                  False     False
# 455                  False                  False     False
# 523                  False                  False     False
# 554                  False                  False     False
# 582                  False                  False     False
# 599                  False                  False     False
# 612                  False                  False     False
# 633                  False                  False     False
# 659                  False                  False     False
# 666                  False                  False     False
# 689                  False                  False     False
# 707                  False                  False     False
# 710                  False                  False     False
# 756                  False                  False     False
# 775                  False                  False     False
# 779                  False                  False     False
# 818                  False                  False     False
# 837                  False                  False     False
# 842                  False                  False     False
# 858                  False                  False     False
# 886                  False                  False     False
# 893                  False                  False     False
# 909                  False                  False     False
# 944                  False                  False     False
# 972                  False                  False     False
# 979                  False                  False     False
# 999                  False                  False     False
# 1005                 False                  False     False
#
#                       budget_flag roi_flag revenue_flag  net_profit
# 12                          False    False        False -32657.3500
# 22                          False    False        False  -7361.5500
# 26                          False    False        False -85267.3876
# 58                          False    False        False -49645.3200
# 81                          False    False        False -24370.4400
# 200                         False    False        False -52888.9300
# 237                         False    False        False -68489.0900
# 253                         False    False        False -50607.2800
# 264                         False    False        False -35169.4000
# 266                         False    False        False -31205.2500
# 277                         False    False        False -61349.2200
# 292                         False    False        False -11164.9900
# 327                         False    False        False -91068.4776
# 381                         False    False        False  -6771.5500
# 412                         False    False        False -83260.4900
# 424                         False    False        False  -7365.0000
# 455                         False    False        False -17355.5200
# 523                         False    False        False -13919.4000
# 554                         False    False        False -53452.3400
# 582                         False    False        False -37339.5700
# 599                         False    False        False -77408.2000
# 612                         False    False        False  -7660.0400
# 633                         False    False        False -29121.3900
# 659                         False    False        False -16158.0700
# 666                         False    False        False -47273.7800
# 689                         False    False        False  -2916.5400
# 707                         False    False        False -91718.6976
# 710                         False    False        False -57421.0700
# 756                         False    False        False -10693.2500
# 775                         False    False        False -52116.9000
# 779                         False    False        False -36544.6400
# 818                         False    False        False -31082.2000
# 837                         False    False        False -69612.8100
# 842                         False    False        False  -8871.8200
# 858                         False    False        False  -7746.4900
# 886                         False    False        False -61869.8900
# 893                         False    False        False -17978.3000
# 909                         False    False        False -55977.8900
# 944                         False    False        False -26617.5100
# 972                         False    False        False -67005.3100
# 979                         False    False        False -60794.9700
# 999   Suspiciously high (outlier)    False        False -49340.9776
# 1005                        False    False        False -20000.0000

# %%
# Ensure net_profit is numeric
merged_df_final['net_profit'] = pd.to_numeric(merged_df_final['net_profit'], errors='coerce')

# Assign quarter
merged_df_final['quarter'] = pd.to_datetime(merged_df_final['start_date'], errors='coerce').dt.to_period('Q').astype(str)

# Build bottom campaigns
worst_campaigns_by_quarter = {}

for q in sorted(merged_df_final['quarter'].dropna().unique()):
    quarter_data = merged_df_final[merged_df_final['quarter'] == q]
    quarter_data = quarter_data.dropna(subset=['net_profit'])

    bottom_5 = (
        quarter_data
        .sort_values(by='net_profit', ascending=True)
        .head(5)[['campaign_name', 'net_profit', 'roi', 'channel', 'type']]
        .round(2)
        .to_dict(orient='records')
    )
    worst_campaigns_by_quarter[q] = bottom_5
worst_campaigns_by_quarter
# Out:
# {'2022Q3': [{'campaign_name': 'horizontal asymmetric contingency',
#    'net_profit': -91718.7,
#    'roi': 0.23,
#    'channel': 'referral',
#    'type': 'email'},
#   {'campaign_name': 'multi-lateral 6thgeneration benchmark',
#    'net_profit': -77408.2,
#    'roi': 0.51,
#    'channel': 'promotion',
#    'type': 'podcast'},
#   {'campaign_name': 'reduced mobile matrices',
#    'net_profit': -11164.99,
#    'roi': 0.74,
#    'channel': 'promotion',
#    'type': 'webinar'},
#   {'campaign_name': 'right-sized next generation solution',
#    'net_profit': -10693.25,
#    'roi': 0.54,
#    'channel': 'referral',
#    'type': 'podcast'},
#   {'campaign_name': 'programmable homogeneous projection',
#    'net_profit': -7365.0,
#    'roi': 0.25,
#    'channel': 'promotion',
#    'type': 'podcast'}],
#  '2022Q4': [{'campaign_name': 'persistent radical approach',
#    'net_profit': -91068.48,
#    'roi': 0.8,
#    'channel': 'promotion',
#    'type': 'email'},
#   {'campaign_name': 'seamless clear-thinking product',
#    'net_profit': -85267.39,
#    'roi': 0.63,
#    'channel': 'organic',
#    'type': 'email'},
#   {'campaign_name': 'de-engineered static standardization',
#    'net_profit': -55977.89,
#    'roi': 0.46,
#    'channel': 'promotion',
#    'type': 'email'},
#   {'campaign_name': 'proactive bifurcated architecture',
#    'net_profit': -53452.34,
#    'roi': 0.85,
#    'channel': 'promotion',
#    'type': 'email'},
#   {'campaign_name': 'focused responsive open architecture',
#    'net_profit': -52888.93,
#    'roi': 0.93,
#    'channel': 'referral',
#    'type': 'webinar'}],
#  '2023Q1': [{'campaign_name': 'grass-roots scalable framework',
#    'net_profit': -61869.89,
#    'roi': 0.39,
#    'channel': 'paid',
#    'type': 'social media'},
#   {'campaign_name': 'automated 5thgeneration attitude',
#    'net_profit': -61349.22,
#    'roi': 0.99,
#    'channel': 'referral',
#    'type': 'email'},
#   {'campaign_name': 'universal asymmetric extranet',
#    'net_profit': -60794.97,
#    'roi': 0.6,
#    'channel': 'referral',
#    'type': 'webinar'},
#   {'campaign_name': 'polarized client-driven moratorium',
#    'net_profit': -36544.64,
#    'roi': 0.13,
#    'channel': 'referral',
#    'type': 'webinar'},
#   {'campaign_name': 're-contextualized regional pricing structure',
#    'net_profit': -35169.4,
#    'roi': 0.44,
#    'channel': 'promotion',
#    'type': 'email'}],
#  '2023Q2': [{'campaign_name': 'reduced high-level methodology',
#    'net_profit': -83260.49,
#    'roi': 0.48,
#    'channel': 'organic',
#    'type': 'email'},
#   {'campaign_name': 'compatible local concept',
#    'net_profit': -69612.81,
#    'roi': 0.81,
#    'channel': 'referral',
#    'type': 'webinar'},
#   {'campaign_name': 'decentralized incremental synergy',
#    'net_profit': -68489.09,
#    'roi': 0.81,
#    'channel': 'referral',
#    'type': 'social media'},
#   {'campaign_name': 'face-to-face scalable definition',
#    'net_profit': -52116.9,
#    'roi': 0.88,
#    'channel': 'paid',
#    'type': 'podcast'},
#   {'campaign_name': 'persevering web-enabled workforce',
#    'net_profit': -49645.32,
#    'roi': 0.6,
#    'channel': 'paid',
#    'type': 'social media'}],
#  '2023Q3': [{'campaign_name': 'extended 24hour contingency',
#    'net_profit': -67005.31,
#    'roi': 0.16,
#    'channel': 'organic',
#    'type': 'podcast'},
#   {'campaign_name': 'synergized mission-critical conglomeration',
#    'net_profit': -57421.07,
#    'roi': 0.38,
#    'channel': 'organic',
#    'type': 'webinar'},
#   {'campaign_name': 'outlier budget',
#    'net_profit': -49340.98,
#    'roi': 0.1,
#    'channel': 'promotion',
#    'type': 'email'},
#   {'campaign_name': 'universal uniform service-desk',
#    'net_profit': -31082.2,
#    'roi': 0.39,
#    'channel': 'referral',
#    'type': 'email'},
#   {'campaign_name': 'enterprise-wide tangible secured line',
#    'net_profit': -17978.3,
#    'roi': 0.4,
#    'channel': 'promotion',
#    'type': 'email'}],
#  '2023Q4': [{'campaign_name': 'new campaign - missing budget',
#    'net_profit': 45000.0,
#    'roi': 0.25,
#    'channel': 'organic',
#    'type': 'email'}],
#  '2025Q1': [{'campaign_name': 'future campaign',
#    'net_profit': 125000.0,
#    'roi': 0.9,
#    'channel': 'promotion',
#    'type': 'webinar'}]}

# %%
merged_df_final.sort_values(by='net_profit', ascending=True).head(5)[['campaign_name', 'net_profit', 'roi', 'channel', 'type']].round(2).to_dict(orient='records')
# Out:
# [{'campaign_name': 'horizontal asymmetric contingency',
#   'net_profit': -91718.7,
#   'roi': 0.23,
#   'channel': 'referral',
#   'type': 'email'},
#  {'campaign_name': 'persistent radical approach',
#   'net_profit': -91068.48,
#   'roi': 0.8,
#   'channel': 'promotion',
#   'type': 'email'},
#  {'campaign_name': 'seamless clear-thinking product',
#   'net_profit': -85267.39,
#   'roi': 0.63,
#   'channel': 'organic',
#   'type': 'email'},
#  {'campaign_name': 'reduced high-level methodology',
#   'net_profit': -83260.49,
#   'roi': 0.48,
#   'channel': 'organic',
#   'type': 'email'},
#  {'campaign_name': 'multi-lateral 6thgeneration benchmark',
#   'net_profit': -77408.2,
#   'roi': 0.51,
#   'channel': 'promotion',
#   'type': 'podcast'}]

# %%
print(merged_df_final[merged_df_final['net_profit'] < 0].groupby('quarter').size())
# Out:
# quarter
# 2022Q3     6
# 2022Q4    10
# 2023Q1    10
# 2023Q2    12
# 2023Q3     5
# dtype: int64

# %%
merged_df_final.to_csv('cleaned_marketing_campaigns.csv', index=False)
